# %% [markdown]
# ## Handling missing data

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Chembl_library_2M_2.csv')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920333  CHEMBL1627004                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# ...

# %%
df.isnull()
# df.isna()
# Out:
#          ChEMBLID   Name  Synonyms   Type  MaxPhase  MolecularWeight  Targets  \
# 0           False   True      True  False     False            False    False
# 1           False   True      True  False     False            False    False
# 2           False   True      True  False     False            False    False
# 3           False   True      True  False     False            False    False
# 4           False   True      True  False     False            False    False
# ...           ...    ...       ...    ...       ...              ...      ...
# 1920333     False   True      True  False     False            False    False
# 1920334     False  False     False  False     False            False    False
# 1920335     False  False     False  False     False            False     True
# 1920336     False   True      True  False     False            False    False
# 1920337     False  False     False  False     False            False    False
#
# ...

# %%
df.isna().sum()
# Out:
# ChEMBLID                               0
# Name                             1877058
# Synonyms                         1836211
# Type                                   0
# MaxPhase                               0
# MolecularWeight                     2085
# Targets                            84701
# Bioactivities                      84701
# AlogP                              33904
# PolarSurfaceArea                    2085
# HBA                                 2085
# HBD                                 2085
# #RO5Violations                      2085
# #RotatableBonds                     2085
# PassesRo3                           2085
# QEDWeighted                         2085
# CXAcidicpKa                         2085
# CXBasicpKa                          2085
# CXLogP                              2085
# CXLogD                              2085
# AromaticRings                       2085
# StructureType                          0
# InorganicFlag                          0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 3969247

# %%
df.MolecularWeight.isnull().sum()
# Out:
# 2085

# %%
df.isnull().mean() # Percetage of missing data
# Out:
# ChEMBLID                         0.000000
# Name                             0.977462
# Synonyms                         0.956192
# Type                             0.000000
# MaxPhase                         0.000000
# MolecularWeight                  0.001086
# Targets                          0.044107
# Bioactivities                    0.044107
# AlogP                            0.017655
# PolarSurfaceArea                 0.001086
# HBA                              0.001086
# HBD                              0.001086
# #RO5Violations                   0.001086
# #RotatableBonds                  0.001086
# PassesRo3                        0.001086
# QEDWeighted                      0.001086
# CXAcidicpKa                      0.001086
# CXBasicpKa                       0.001086
# CXLogP                           0.001086
# CXLogD                           0.001086
# AromaticRings                    0.001086
# StructureType                    0.000000
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#               ChEMBLID              Name  \
# 0        CHEMBL3425773               NaN
# 1        CHEMBL1998753               NaN
# 2        CHEMBL1867860               NaN
# 3         CHEMBL481686               NaN
# 4        CHEMBL1939547               NaN
# ...                ...               ...
# 1920331  CHEMBL3249871               NaN
# 1920332  CHEMBL3318948               NaN
# 1920333  CHEMBL1627004               NaN
# 1920335  CHEMBL1201377  MISOPROSTOL ACID
# 1920336   CHEMBL537710               NaN
#
#                                              Synonyms            Type  \
# 0                                                 NaN  Small molecule
# 1                                                 NaN  Small molecule
# 2                                                 NaN  Small molecule
# 3                                                 NaN  Small molecule
# 4                                                 NaN  Small molecule
# ...

# %%
df[df.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ChEMBLID, Name, Synonyms, Type, MaxPhase, MolecularWeight, Targets, Bioactivities, AlogP, PolarSurfaceArea, HBA, HBD, #RO5Violations, #RotatableBonds, PassesRo3, QEDWeighted, CXAcidicpKa, CXBasicpKa, CXLogP, CXLogD, AromaticRings, StructureType, InorganicFlag, HeavyAtoms, HBA(Lipinski), HBD(Lipinski), #RO5Violations(Lipinski), MolecularWeight(Monoisotopic), MolecularSpecies, MolecularFormula, Smiles, InchiKey]
# Index: []
#
# [0 rows x 32 columns]

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
df.notna()
# Out:
#          ChEMBLID   Name  Synonyms  Type  MaxPhase  MolecularWeight  Targets  \
# 0            True  False     False  True      True             True     True
# 1            True  False     False  True      True             True     True
# 2            True  False     False  True      True             True     True
# 3            True  False     False  True      True             True     True
# 4            True  False     False  True      True             True     True
# ...           ...    ...       ...   ...       ...              ...      ...
# 1920333      True  False     False  True      True             True     True
# 1920334      True   True      True  True      True             True     True
# 1920335      True   True      True  True      True             True    False
# 1920336      True  False     False  True      True             True     True
# 1920337      True   True      True  True      True             True     True
#
# ...

# %%
df.notna().sum()
# Out:
# ChEMBLID                         1920338
# Name                               43280
# Synonyms                           84127
# Type                             1920338
# MaxPhase                         1920338
# MolecularWeight                  1918253
# Targets                          1835637
# Bioactivities                    1835637
# AlogP                            1886434
# PolarSurfaceArea                 1918253
# HBA                              1918253
# HBD                              1918253
# #RO5Violations                   1918253
# #RotatableBonds                  1918253
# PassesRo3                        1918253
# QEDWeighted                      1918253
# CXAcidicpKa                      1918253
# CXBasicpKa                       1918253
# CXLogP                           1918253
# CXLogD                           1918253
# AromaticRings                    1918253
# StructureType                    1920338
# InorganicFlag                    1920338
# ...

# %%
df.notna().sum().sum()      # df.notnull().sum().sum()
# Out:
# 57481569

# %%
df.isnull().sum().sum()
# Out:
# 3969247

# %%
df.size            # df.size = df.isnull().sum().sum() + df.notna().sum().sum()
# Out:
# 61450816
