# %% [markdown]
# ### Fill nan **values**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Chembl_library_2M_2.csv')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920333  CHEMBL1627004                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# ...

# %%
df2 = df.iloc[1995:2995, ]
df2
# Out:
#            ChEMBLID Name Synonyms            Type  MaxPhase  MolecularWeight  \
# 1995  CHEMBL1455492  NaN      NaN  Small molecule         0           494.43
# 1996  CHEMBL1982341  NaN      NaN  Small molecule         0           313.30
# 1997  CHEMBL1337497  NaN      NaN  Small molecule         0           331.42
# 1998    CHEMBL77427  NaN      NaN  Small molecule         0           253.24
# 1999  CHEMBL1801505  NaN      NaN  Small molecule         0           381.39
# ...             ...  ...      ...             ...       ...              ...
# 2990   CHEMBL525135  NaN      NaN  Small molecule         0           502.70
# 2991  CHEMBL1532982  NaN      NaN  Small molecule         0           450.50
# 2992  CHEMBL1179326  NaN      NaN  Small molecule         0           450.64
# 2993  CHEMBL4237968  NaN      NaN  Small molecule         0           288.35
# 2994  CHEMBL3554562  NaN      NaN  Small molecule         0           322.47
#
# ...

# %%
df2.fillna('')
# df = df.fillna('') or df2 = df.fillna('') or df.fillna(inplace=True) => To save changes, you should update the DataFrame or define a new DataFrame. Alternatively, you can use 'inplace' parameter to update your DataFram.
# Out:
#            ChEMBLID Name Synonyms            Type  MaxPhase  MolecularWeight  \
# 1995  CHEMBL1455492                Small molecule         0           494.43
# 1996  CHEMBL1982341                Small molecule         0           313.30
# 1997  CHEMBL1337497                Small molecule         0           331.42
# 1998    CHEMBL77427                Small molecule         0           253.24
# 1999  CHEMBL1801505                Small molecule         0           381.39
# ...             ...  ...      ...             ...       ...              ...
# 2990   CHEMBL525135                Small molecule         0           502.70
# 2991  CHEMBL1532982                Small molecule         0           450.50
# 2992  CHEMBL1179326                Small molecule         0           450.64
# 2993  CHEMBL4237968                Small molecule         0           288.35
# 2994  CHEMBL3554562                Small molecule         0           322.47
#
# ...

# %%
df2.fillna('None')
# Out:
#            ChEMBLID  Name Synonyms            Type  MaxPhase  MolecularWeight  \
# 1995  CHEMBL1455492  None     None  Small molecule         0           494.43
# 1996  CHEMBL1982341  None     None  Small molecule         0           313.30
# 1997  CHEMBL1337497  None     None  Small molecule         0           331.42
# 1998    CHEMBL77427  None     None  Small molecule         0           253.24
# 1999  CHEMBL1801505  None     None  Small molecule         0           381.39
# ...             ...   ...      ...             ...       ...              ...
# 2990   CHEMBL525135  None     None  Small molecule         0           502.70
# 2991  CHEMBL1532982  None     None  Small molecule         0           450.50
# 2992  CHEMBL1179326  None     None  Small molecule         0           450.64
# 2993  CHEMBL4237968  None     None  Small molecule         0           288.35
# 2994  CHEMBL3554562  None     None  Small molecule         0           322.47
#
# ...

# %%
df.fillna(0)
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                  0
# 1        CHEMBL1998753                  0
# 2        CHEMBL1867860                  0
# 3         CHEMBL481686                  0
# 4        CHEMBL1939547                  0
# ...                ...                ...
# 1920333  CHEMBL1627004                  0
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                  0
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                        0  Small molecule
# 1                                                        0  Small molecule
# 2                                                        0  Small molecule
# 3                                                        0  Small molecule
# 4                                                        0  Small molecule
# ...

# %%
df2['Name'].fillna('')
# Out:
# 1995
# 1996
# 1997
# 1998
# 1999
#        ..
# 2990
# 2991
# 2992
# 2993
# 2994
# Name: Name, Length: 1000, dtype: object

# %%
df2[['Name', 'AlogP']].fillna('')
# Out:
#      Name AlogP
# 1995       2.21
# 1996
# 1997       1.76
# 1998       0.22
# 1999       3.65
# ...   ...   ...
# 2990       7.19
# 2991       1.91
# 2992       5.15
# 2993       2.63
# 2994       3.08
#
# [1000 rows x 2 columns]

# %%
df2.fillna({'Name':0, 'Synonyms':''})
# Out:
#            ChEMBLID Name Synonyms            Type  MaxPhase  MolecularWeight  \
# 1995  CHEMBL1455492    0           Small molecule         0           494.43
# 1996  CHEMBL1982341    0           Small molecule         0           313.30
# 1997  CHEMBL1337497    0           Small molecule         0           331.42
# 1998    CHEMBL77427    0           Small molecule         0           253.24
# 1999  CHEMBL1801505    0           Small molecule         0           381.39
# ...             ...  ...      ...             ...       ...              ...
# 2990   CHEMBL525135    0           Small molecule         0           502.70
# 2991  CHEMBL1532982    0           Small molecule         0           450.50
# 2992  CHEMBL1179326    0           Small molecule         0           450.64
# 2993  CHEMBL4237968    0           Small molecule         0           288.35
# 2994  CHEMBL3554562    0           Small molecule         0           322.47
#
# ...

# %%
df2
# Out:
#            ChEMBLID Name Synonyms            Type  MaxPhase  MolecularWeight  \
# 1995  CHEMBL1455492  NaN      NaN  Small molecule         0           494.43
# 1996  CHEMBL1982341  NaN      NaN  Small molecule         0           313.30
# 1997  CHEMBL1337497  NaN      NaN  Small molecule         0           331.42
# 1998    CHEMBL77427  NaN      NaN  Small molecule         0           253.24
# 1999  CHEMBL1801505  NaN      NaN  Small molecule         0           381.39
# ...             ...  ...      ...             ...       ...              ...
# 2990   CHEMBL525135  NaN      NaN  Small molecule         0           502.70
# 2991  CHEMBL1532982  NaN      NaN  Small molecule         0           450.50
# 2992  CHEMBL1179326  NaN      NaN  Small molecule         0           450.64
# 2993  CHEMBL4237968  NaN      NaN  Small molecule         0           288.35
# 2994  CHEMBL3554562  NaN      NaN  Small molecule         0           322.47
#
# ...

# %%
df2.fillna(method='ffill')
# Out:
#            ChEMBLID          Name                              Synonyms  \
# 1995  CHEMBL1455492           NaN                                   NaN
# 1996  CHEMBL1982341           NaN                                   NaN
# 1997  CHEMBL1337497           NaN                                   NaN
# 1998    CHEMBL77427           NaN                                   NaN
# 1999  CHEMBL1801505           NaN                                   NaN
# ...             ...           ...                                   ...
# 2990   CHEMBL525135  TROPENZILINE  TROPENZILINE CATION|TROPENZILINE ION
# 2991  CHEMBL1532982  TROPENZILINE  TROPENZILINE CATION|TROPENZILINE ION
# 2992  CHEMBL1179326  TROPENZILINE  TROPENZILINE CATION|TROPENZILINE ION
# 2993  CHEMBL4237968  TROPENZILINE  TROPENZILINE CATION|TROPENZILINE ION
# 2994  CHEMBL3554562  TROPENZILINE  TROPENZILINE CATION|TROPENZILINE ION
#
#                 Type  MaxPhase  MolecularWeight  Targets  Bioactivities  \
# ...

# %%
df2.fillna(method='ffill', axis=1)
# Out:
#            ChEMBLID           Name       Synonyms            Type MaxPhase  \
# 1995  CHEMBL1455492  CHEMBL1455492  CHEMBL1455492  Small molecule        0
# 1996  CHEMBL1982341  CHEMBL1982341  CHEMBL1982341  Small molecule        0
# 1997  CHEMBL1337497  CHEMBL1337497  CHEMBL1337497  Small molecule        0
# 1998    CHEMBL77427    CHEMBL77427    CHEMBL77427  Small molecule        0
# 1999  CHEMBL1801505  CHEMBL1801505  CHEMBL1801505  Small molecule        0
# ...             ...            ...            ...             ...      ...
# 2990   CHEMBL525135   CHEMBL525135   CHEMBL525135  Small molecule        0
# 2991  CHEMBL1532982  CHEMBL1532982  CHEMBL1532982  Small molecule        0
# 2992  CHEMBL1179326  CHEMBL1179326  CHEMBL1179326  Small molecule        0
# 2993  CHEMBL4237968  CHEMBL4237968  CHEMBL4237968  Small molecule        0
# 2994  CHEMBL3554562  CHEMBL3554562  CHEMBL3554562  Small molecule        0
#
# ...

# %%
df2.fillna(method='pad')
# Out:
#            ChEMBLID          Name                              Synonyms  \
# 1995  CHEMBL1455492           NaN                                   NaN
# 1996  CHEMBL1982341           NaN                                   NaN
# 1997  CHEMBL1337497           NaN                                   NaN
# 1998    CHEMBL77427           NaN                                   NaN
# 1999  CHEMBL1801505           NaN                                   NaN
# ...             ...           ...                                   ...
# 2990   CHEMBL525135  TROPENZILINE  TROPENZILINE CATION|TROPENZILINE ION
# 2991  CHEMBL1532982  TROPENZILINE  TROPENZILINE CATION|TROPENZILINE ION
# 2992  CHEMBL1179326  TROPENZILINE  TROPENZILINE CATION|TROPENZILINE ION
# 2993  CHEMBL4237968  TROPENZILINE  TROPENZILINE CATION|TROPENZILINE ION
# 2994  CHEMBL3554562  TROPENZILINE  TROPENZILINE CATION|TROPENZILINE ION
#
#                 Type  MaxPhase  MolecularWeight  Targets  Bioactivities  \
# ...

# %%
df2.fillna(method='pad', axis=1)
# Out:
#            ChEMBLID           Name       Synonyms            Type MaxPhase  \
# 1995  CHEMBL1455492  CHEMBL1455492  CHEMBL1455492  Small molecule        0
# 1996  CHEMBL1982341  CHEMBL1982341  CHEMBL1982341  Small molecule        0
# 1997  CHEMBL1337497  CHEMBL1337497  CHEMBL1337497  Small molecule        0
# 1998    CHEMBL77427    CHEMBL77427    CHEMBL77427  Small molecule        0
# 1999  CHEMBL1801505  CHEMBL1801505  CHEMBL1801505  Small molecule        0
# ...             ...            ...            ...             ...      ...
# 2990   CHEMBL525135   CHEMBL525135   CHEMBL525135  Small molecule        0
# 2991  CHEMBL1532982  CHEMBL1532982  CHEMBL1532982  Small molecule        0
# 2992  CHEMBL1179326  CHEMBL1179326  CHEMBL1179326  Small molecule        0
# 2993  CHEMBL4237968  CHEMBL4237968  CHEMBL4237968  Small molecule        0
# 2994  CHEMBL3554562  CHEMBL3554562  CHEMBL3554562  Small molecule        0
#
# ...

# %%
df2
# Out:
#            ChEMBLID Name Synonyms            Type  MaxPhase  MolecularWeight  \
# 1995  CHEMBL1455492  NaN      NaN  Small molecule         0           494.43
# 1996  CHEMBL1982341  NaN      NaN  Small molecule         0           313.30
# 1997  CHEMBL1337497  NaN      NaN  Small molecule         0           331.42
# 1998    CHEMBL77427  NaN      NaN  Small molecule         0           253.24
# 1999  CHEMBL1801505  NaN      NaN  Small molecule         0           381.39
# ...             ...  ...      ...             ...       ...              ...
# 2990   CHEMBL525135  NaN      NaN  Small molecule         0           502.70
# 2991  CHEMBL1532982  NaN      NaN  Small molecule         0           450.50
# 2992  CHEMBL1179326  NaN      NaN  Small molecule         0           450.64
# 2993  CHEMBL4237968  NaN      NaN  Small molecule         0           288.35
# 2994  CHEMBL3554562  NaN      NaN  Small molecule         0           322.47
#
# ...

# %%
df2.fillna(method='bfill')
# Out:
#            ChEMBLID                     Name               Synonyms  \
# 1995  CHEMBL1455492  5-HYDROXYISOZALUZANIN C  N-nonyl noeurostegine
# 1996  CHEMBL1982341  5-HYDROXYISOZALUZANIN C  N-nonyl noeurostegine
# 1997  CHEMBL1337497  5-HYDROXYISOZALUZANIN C  N-nonyl noeurostegine
# 1998    CHEMBL77427  5-HYDROXYISOZALUZANIN C  N-nonyl noeurostegine
# 1999  CHEMBL1801505  5-HYDROXYISOZALUZANIN C  N-nonyl noeurostegine
# ...             ...                      ...                    ...
# 2990   CHEMBL525135                      NaN                    NaN
# 2991  CHEMBL1532982                      NaN                    NaN
# 2992  CHEMBL1179326                      NaN                    NaN
# 2993  CHEMBL4237968                      NaN                    NaN
# 2994  CHEMBL3554562                      NaN                    NaN
#
#                 Type  MaxPhase  MolecularWeight  Targets  Bioactivities  \
# 1995  Small molecule         0           494.43      9.0           11.0
# ...

# %%
df2.fillna(method='bfill', axis=1)
# Out:
#            ChEMBLID            Name        Synonyms            Type MaxPhase  \
# 1995  CHEMBL1455492  Small molecule  Small molecule  Small molecule        0
# 1996  CHEMBL1982341  Small molecule  Small molecule  Small molecule        0
# 1997  CHEMBL1337497  Small molecule  Small molecule  Small molecule        0
# 1998    CHEMBL77427  Small molecule  Small molecule  Small molecule        0
# 1999  CHEMBL1801505  Small molecule  Small molecule  Small molecule        0
# ...             ...             ...             ...             ...      ...
# 2990   CHEMBL525135  Small molecule  Small molecule  Small molecule        0
# 2991  CHEMBL1532982  Small molecule  Small molecule  Small molecule        0
# 2992  CHEMBL1179326  Small molecule  Small molecule  Small molecule        0
# 2993  CHEMBL4237968  Small molecule  Small molecule  Small molecule        0
# 2994  CHEMBL3554562  Small molecule  Small molecule  Small molecule        0
#
# ...

# %%
df2.fillna(method='backfill')
# Out:
#            ChEMBLID                     Name               Synonyms  \
# 1995  CHEMBL1455492  5-HYDROXYISOZALUZANIN C  N-nonyl noeurostegine
# 1996  CHEMBL1982341  5-HYDROXYISOZALUZANIN C  N-nonyl noeurostegine
# 1997  CHEMBL1337497  5-HYDROXYISOZALUZANIN C  N-nonyl noeurostegine
# 1998    CHEMBL77427  5-HYDROXYISOZALUZANIN C  N-nonyl noeurostegine
# 1999  CHEMBL1801505  5-HYDROXYISOZALUZANIN C  N-nonyl noeurostegine
# ...             ...                      ...                    ...
# 2990   CHEMBL525135                      NaN                    NaN
# 2991  CHEMBL1532982                      NaN                    NaN
# 2992  CHEMBL1179326                      NaN                    NaN
# 2993  CHEMBL4237968                      NaN                    NaN
# 2994  CHEMBL3554562                      NaN                    NaN
#
#                 Type  MaxPhase  MolecularWeight  Targets  Bioactivities  \
# 1995  Small molecule         0           494.43      9.0           11.0
# ...

# %%
df2.fillna(method='backfill', axis=1)
# Out:
#            ChEMBLID            Name        Synonyms            Type MaxPhase  \
# 1995  CHEMBL1455492  Small molecule  Small molecule  Small molecule        0
# 1996  CHEMBL1982341  Small molecule  Small molecule  Small molecule        0
# 1997  CHEMBL1337497  Small molecule  Small molecule  Small molecule        0
# 1998    CHEMBL77427  Small molecule  Small molecule  Small molecule        0
# 1999  CHEMBL1801505  Small molecule  Small molecule  Small molecule        0
# ...             ...             ...             ...             ...      ...
# 2990   CHEMBL525135  Small molecule  Small molecule  Small molecule        0
# 2991  CHEMBL1532982  Small molecule  Small molecule  Small molecule        0
# 2992  CHEMBL1179326  Small molecule  Small molecule  Small molecule        0
# 2993  CHEMBL4237968  Small molecule  Small molecule  Small molecule        0
# 2994  CHEMBL3554562  Small molecule  Small molecule  Small molecule        0
#
# ...

# %%
df.head()
# Out:
#         ChEMBLID Name Synonyms            Type  MaxPhase  MolecularWeight  \
# 0  CHEMBL3425773  NaN      NaN  Small molecule         0           263.25
# 1  CHEMBL1998753  NaN      NaN  Small molecule         0           455.46
# 2  CHEMBL1867860  NaN      NaN  Small molecule         0           465.53
# 3   CHEMBL481686  NaN      NaN  Small molecule         0           417.55
# 4  CHEMBL1939547  NaN      NaN  Small molecule         0           328.31
#
#    Targets  Bioactivities  AlogP PolarSurfaceArea  ... InorganicFlag  \
# 0      1.0            1.0   3.04            74.23  ...            -1
# 1     56.0           56.0   2.28           100.60  ...            -1
# 2      4.0            4.0   3.49            91.56  ...            -1
# 3      1.0            2.0   4.71            48.71  ...            -1
# 4      5.0           10.0   3.69           112.06  ...            -1
#
#   HeavyAtoms HBA(Lipinski) HBD(Lipinski) #RO5Violations(Lipinski)  \
# ...

# %%
df.MolecularWeight.count()
# Out:
# 1918253

# %%
df.MolecularWeight.mean()
# Out:
# 418.46549349851114

# %%
df['MolecularWeight'].fillna(df['MolecularWeight'].mean())
# Out:
# 0           263.25
# 1           455.46
# 2           465.53
# 3           417.55
# 4           328.31
#             ...
# 1920333    1815.46
# 1920334     450.53
# 1920335     368.51
# 1920336     375.76
# 1920337     289.32
# Name: MolecularWeight, Length: 1920338, dtype: float64

# %%
df.MolecularWeight.count()
# Out:
# 1918253

# %%
df.MolecularWeight.isnull().sum()
# Out:
# 2085

# %%
len(df)
# Out:
# 1920338

# %%
df['MolecularWeight'] = df['MolecularWeight'].fillna(df['MolecularWeight'].mean())
df['MolecularWeight'].count()

# df['MolecularWeight'].fillna(df['MolecularWeight'].mean())       => Correct but unwanted
# df3 = df['MolecularWeight'].fillna(df['MolecularWeight'].mean()) => Correct but unwanted
# df4 = df[df['MolecularWeight'].fillna(df['MolecularWeight'].mean())] => What about this one?
# Out:
# 1920338

# %%
df.MolecularWeight.value_counts()
# Out:
# 418.465493     2085
# 326.400000     1196
# 321.380000     1081
# 337.380000     1064
# 342.400000     1057
#                ...
# 1167.000000       1
# 880.560000        1
# 27.010000         1
# 683.360000        1
# 1815.460000       1
# Name: MolecularWeight, Length: 77828, dtype: int64

# %%
df.MolecularWeight.mean()
# Out:
# 418.46549349851153

# %%
df['AlogP'].isnull().sum()
# Out:
# 33904

# %%
df['AlogP'] = df['AlogP'].interpolate(method='linear')  # Read more: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.interpolate.html
df
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920333  CHEMBL1627004                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 1                                                      NaN  Small molecule
# 2                                                      NaN  Small molecule
# 3                                                      NaN  Small molecule
# 4                                                      NaN  Small molecule
# ...

# %% [markdown]
# ### Remove missing values

# %%
df.head()
# Out:
#         ChEMBLID Name Synonyms            Type  MaxPhase  MolecularWeight  \
# 0  CHEMBL3425773  NaN      NaN  Small molecule         0           263.25
# 1  CHEMBL1998753  NaN      NaN  Small molecule         0           455.46
# 2  CHEMBL1867860  NaN      NaN  Small molecule         0           465.53
# 3   CHEMBL481686  NaN      NaN  Small molecule         0           417.55
# 4  CHEMBL1939547  NaN      NaN  Small molecule         0           328.31
#
#    Targets  Bioactivities  AlogP PolarSurfaceArea  ... InorganicFlag  \
# 0      1.0            1.0   3.04            74.23  ...            -1
# 1     56.0           56.0   2.28           100.60  ...            -1
# 2      4.0            4.0   3.49            91.56  ...            -1
# 3      1.0            2.0   4.71            48.71  ...            -1
# 4      5.0           10.0   3.69           112.06  ...            -1
#
#   HeavyAtoms HBA(Lipinski) HBD(Lipinski) #RO5Violations(Lipinski)  \
# ...

# %%
df.dropna(how='any')                     # DataFrame.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# Out:
#               ChEMBLID                     Name  \
# 23        CHEMBL325439                 BEPAFANT
# 79        CHEMBL444657           KALAMBROSIDE C
# 82        CHEMBL541930    OLEYLPHOSPHONOCHOLINE
# 163       CHEMBL458693           VERONGIAQUINOL
# 186       CHEMBL466041  OCTADECYLPHOSPHOCHOLINE
# ...                ...                      ...
# 1920310  CHEMBL1334692                LONAZOLAC
# 1920312    CHEMBL21536               XANOMELINE
# 1920314  CHEMBL4303615             ERCALCITRIOL
# 1920334  CHEMBL3958686            REMOGLIFLOZIN
# 1920337      CHEMBL906        MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 23                              BEPAFANT|Bepafant|WEB-2170  Small molecule
# 79                                          kalambroside C  Small molecule
# 82                                   Oleylphosphonocholine  Small molecule
# 163                                         Verongiaquinol  Small molecule
# ...

# %%
df.dropna(how='all')
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920333  CHEMBL1627004                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 1                                                      NaN  Small molecule
# 2                                                      NaN  Small molecule
# 3                                                      NaN  Small molecule
# 4                                                      NaN  Small molecule
# ...

# %%
df.dropna(how='all', axis=1)
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920333  CHEMBL1627004                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 1                                                      NaN  Small molecule
# 2                                                      NaN  Small molecule
# 3                                                      NaN  Small molecule
# 4                                                      NaN  Small molecule
# ...

# %%
df.dropna(thresh=len(df)*0.8, axis=1)  #  1920338 * 0.8 = 1536270.4
# Out:
#               ChEMBLID            Type  MaxPhase  MolecularWeight  Targets  \
# 0        CHEMBL3425773  Small molecule         0           263.25      1.0
# 1        CHEMBL1998753  Small molecule         0           455.46     56.0
# 2        CHEMBL1867860  Small molecule         0           465.53      4.0
# 3         CHEMBL481686  Small molecule         0           417.55      1.0
# 4        CHEMBL1939547  Small molecule         0           328.31      5.0
# ...                ...             ...       ...              ...      ...
# 1920333  CHEMBL1627004  Small molecule         0          1815.46      2.0
# 1920334  CHEMBL3958686  Small molecule         0           450.53      4.0
# 1920335  CHEMBL1201377  Small molecule         0           368.51      NaN
# 1920336   CHEMBL537710  Small molecule         0           375.76      1.0
# 1920337      CHEMBL906  Small molecule         0           289.32      3.0
#
# ...

# %%
df.dropna(thresh=1536270.4, axis=1)
# Out:
#               ChEMBLID            Type  MaxPhase  MolecularWeight  Targets  \
# 0        CHEMBL3425773  Small molecule         0           263.25      1.0
# 1        CHEMBL1998753  Small molecule         0           455.46     56.0
# 2        CHEMBL1867860  Small molecule         0           465.53      4.0
# 3         CHEMBL481686  Small molecule         0           417.55      1.0
# 4        CHEMBL1939547  Small molecule         0           328.31      5.0
# ...                ...             ...       ...              ...      ...
# 1920333  CHEMBL1627004  Small molecule         0          1815.46      2.0
# 1920334  CHEMBL3958686  Small molecule         0           450.53      4.0
# 1920335  CHEMBL1201377  Small molecule         0           368.51      NaN
# 1920336   CHEMBL537710  Small molecule         0           375.76      1.0
# 1920337      CHEMBL906  Small molecule         0           289.32      3.0
#
# ...

# %%
df.dropna(thresh=df.shape[1]*0.8, axis=0)
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920333  CHEMBL1627004                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 1                                                      NaN  Small molecule
# 2                                                      NaN  Small molecule
# 3                                                      NaN  Small molecule
# 4                                                      NaN  Small molecule
# ...

# %% [markdown]
# .........................................................

# %%
new_df= df.dropna(thresh=df.shape[1]*0.8, axis=0)
new_df
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920333  CHEMBL1627004                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 1                                                      NaN  Small molecule
# 2                                                      NaN  Small molecule
# 3                                                      NaN  Small molecule
# 4                                                      NaN  Small molecule
# ...

# %%
dropped_rows = df[~df.index.isin(new_df.index)] # Get dropped rows by unary (invert) operation.
dropped_rows
# Out:
#               ChEMBLID         Name                          Synonyms  \
# 260      CHEMBL3526843          NaN                               NaN
# 3650     CHEMBL3348867          NaN                               NaN
# 4623     CHEMBL1984149          NaN                               NaN
# 5307     CHEMBL3527450          NaN                               NaN
# 10483    CHEMBL3545204       QAF805                            QAF805
# ...                ...          ...                               ...
# 1919543  CHEMBL3545385       WX-037                            WX-037
# 1919591  CHEMBL3545236     BPI-9016                BPI-9016|BPI-9016M
# 1919605  CHEMBL3545426       CC-115                            CC-115
# 1919847  CHEMBL3545134   LY-2780301                        LY-2780301
# 1919880  CHEMBL3545180  THELIATINIB  HMPL-309|THELIATINIB|XILIERTINIB
#
#                    Type  MaxPhase  MolecularWeight  Targets  Bioactivities  \
# ...

# %% [markdown]
# .............................................................

# %%
df.AlogP.dropna()
# Out:
# 0          3.040
# 1          2.280
# 2          3.490
# 3          4.710
# 4          3.690
#            ...
# 1920333    2.415
# 1920334    1.330
# 1920335    3.870
# 1920336    0.820
# 1920337   -1.590
# Name: AlogP, Length: 1920338, dtype: float64

# %%
df.dropna(subset=['AlogP'])
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920333  CHEMBL1627004                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 1                                                      NaN  Small molecule
# 2                                                      NaN  Small molecule
# 3                                                      NaN  Small molecule
# 4                                                      NaN  Small molecule
# ...
