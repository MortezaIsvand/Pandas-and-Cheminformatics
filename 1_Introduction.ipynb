# %%
import pandas as pd
import numpy as np

# %%
pd.__version__

# %%
pd.show_versions()  # Showing the pandas' dependencies.

# %%
np.__version__

# %%
! python --version

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
df = pd.read_csv('/content/drive/MyDrive/Chembl_library_2M.csv', sep=';') # Please import your file's path # Use 'sep' or 'delimiter'. There is no difference. Often, the delimiter is a semicolon(;), but comma(,) and space( ) are also possible.
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              ChEMBL ID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920333  CHEMBL1627004                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# ...

# %%
df.shape

# %%
df.shape[0]

# %%
df.shape[1]

# %%
df.size

# %%
len(df)

# %%
df.head() # Give the parenthesis any number you prefer. The default number is 5.

# %%
df.tail()

# %%
df.values

# %%
df.columns

# %%
list(df.columns)

# %%
df.index

# %%
list(df.index)

# %%
df.index.name = 'Molecules'
df.head()

# %%
df.index = np.arange (1, len(df) + 1)# Reset index starting from 1
df.head()

# Method2:    df.index = range(1, df.shape[0] +1)

# %%
df2 = df.sort_index(ascending=False)
df2

# To save changes : 1- Update the DataFrame. 2- Create a new DataFrame.

# 1- Update the DataFrame:
# df = df.sort_index(ascending=False)
# df.sort_index(ascending=False, inplace=True)

# 2- create a new one:
# df2 = df.sort_index(ascending=False)

# Since I wanted to have the first DataFrame without any changes I prefered the second method to save changes. Sometimes you may need to call the first DataFrame you created. Therefore, keep the first DataFrame as much as possible.

# %%
type(df)

# %%
df.dtypes

# %%
df.info()

# %%
df.describe()        # Numerical data.

# %%
df['Molecular Weight'].count()

# %%
df['Molecular Weight'].mean()

# %%
df['Molecular Weight'].min()

# %%
df['Molecular Weight'].max()

# %%
df['Molecular Weight'].std()

# %%
df['Molecular Weight'].median()

# %%
df.query('Molecular Weight == 393.41 ')

# %%
df.query('Targets == 56 ')

# %%
df.query('Molecular Species == "ACID"')

# %%
df['Molecular Species'].unique()

# %%
len(df['Molecular Species'].unique())

# %%
df['Smiles'].unique()

# %%
len(df['Smiles'].unique())

# %%
df.AlogP.nunique()

# %%
len(df.AlogP.unique())

# %%
df['Molecular Weight'].nunique()

# %%
len(df['Molecular Weight'].unique())

# %%
df['Molecular Species'].value_counts()

# %%
df['Molecular Species'].count()

# %%
df['Smiles'].value_counts()
