# %% [markdown]
# ### Filtering

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv('/content/drive/MyDrive/Chembl_library_2M_2.csv')
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         ChEMBLID Name Synonyms            Type  MaxPhase  MolecularWeight  \
# 0  CHEMBL3425773  NaN      NaN  Small molecule         0           263.25
# 1  CHEMBL1998753  NaN      NaN  Small molecule         0           455.46
# 2  CHEMBL1867860  NaN      NaN  Small molecule         0           465.53
# 3   CHEMBL481686  NaN      NaN  Small molecule         0           417.55
# 4  CHEMBL1939547  NaN      NaN  Small molecule         0           328.31
#
#    Targets  Bioactivities  AlogP PolarSurfaceArea  ... InorganicFlag  \
# 0      1.0            1.0   3.04            74.23  ...            -1
# 1     56.0           56.0   2.28           100.60  ...            -1
# 2      4.0            4.0   3.49            91.56  ...            -1
# ...

# %%
df['MolecularWeight'].max()
# Out:
# 12546.32

# %%
df.MolecularWeight.max()
# Out:
# 12546.32

# %%
df.MolecularWeight.min()
# Out:
# 4.0

# %%
df.MolecularWeight.mean()
# Out:
# 418.46549349851114

# %%
df[df.MolecularWeight==510.61]
# Out:
#               ChEMBLID Name Synonyms            Type  MaxPhase  \
# 3139     CHEMBL3661909  NaN      NaN  Small molecule         0
# 6773     CHEMBL3698288  NaN      NaN  Small molecule         0
# 22611    CHEMBL3126237  NaN      NaN  Small molecule         0
# 79405    CHEMBL3397069  NaN      NaN  Small molecule         0
# 113586    CHEMBL351615  NaN      NaN  Small molecule         0
# ...                ...  ...      ...             ...       ...
# 1858584   CHEMBL393401  NaN      NaN  Small molecule         0
# 1859652  CHEMBL2133301  NaN      NaN  Small molecule         0
# 1861547   CHEMBL159990  NaN      NaN  Small molecule         0
# 1886627   CHEMBL313176  NaN      NaN  Small molecule         0
# 1899017   CHEMBL230459  NaN      NaN  Small molecule         0
#
#          MolecularWeight  Targets  Bioactivities  AlogP PolarSurfaceArea  ...  \
# 3139              510.61      1.0            1.0   4.68           106.98  ...
# ...

# %%
df.query('MolecularWeight==510.61')
# Out:
#               ChEMBLID Name Synonyms            Type  MaxPhase  \
# 3139     CHEMBL3661909  NaN      NaN  Small molecule         0
# 6773     CHEMBL3698288  NaN      NaN  Small molecule         0
# 22611    CHEMBL3126237  NaN      NaN  Small molecule         0
# 79405    CHEMBL3397069  NaN      NaN  Small molecule         0
# 113586    CHEMBL351615  NaN      NaN  Small molecule         0
# ...                ...  ...      ...             ...       ...
# 1858584   CHEMBL393401  NaN      NaN  Small molecule         0
# 1859652  CHEMBL2133301  NaN      NaN  Small molecule         0
# 1861547   CHEMBL159990  NaN      NaN  Small molecule         0
# 1886627   CHEMBL313176  NaN      NaN  Small molecule         0
# 1899017   CHEMBL230459  NaN      NaN  Small molecule         0
#
#          MolecularWeight  Targets  Bioactivities  AlogP PolarSurfaceArea  ...  \
# 3139              510.61      1.0            1.0   4.68           106.98  ...
# ...

# %%
df[df.MolecularWeight < 500]
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920331  CHEMBL3249871                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 1                                                      NaN  Small molecule
# 2                                                      NaN  Small molecule
# 3                                                      NaN  Small molecule
# 4                                                      NaN  Small molecule
# ...

# %%
df.query('MolecularWeight < 500')
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920331  CHEMBL3249871                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 1                                                      NaN  Small molecule
# 2                                                      NaN  Small molecule
# 3                                                      NaN  Small molecule
# 4                                                      NaN  Small molecule
# ...

# %%
df[df.MolecularSpecies=='ACID']
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 10       CHEMBL3823770                NaN
# 11         CHEMBL83428                NaN
# 24       CHEMBL1431546                NaN
# 31       CHEMBL1498991                NaN
# ...                ...                ...
# 1920309  CHEMBL2172780  LONAZOLAC CALCIUM
# 1920310  CHEMBL1334692          LONAZOLAC
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 10                                                     NaN  Small molecule
# 11                                                     NaN  Small molecule
# 24                                                     NaN  Small molecule
# 31                                                     NaN  Small molecule
# ...

# %%
df.query('MolecularSpecies=="ACID"')
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 10       CHEMBL3823770                NaN
# 11         CHEMBL83428                NaN
# 24       CHEMBL1431546                NaN
# 31       CHEMBL1498991                NaN
# ...                ...                ...
# 1920309  CHEMBL2172780  LONAZOLAC CALCIUM
# 1920310  CHEMBL1334692          LONAZOLAC
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 10                                                     NaN  Small molecule
# 11                                                     NaN  Small molecule
# 24                                                     NaN  Small molecule
# 31                                                     NaN  Small molecule
# ...

# %%
df.groupby('MolecularSpecies').get_group('ACID')
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 10       CHEMBL3823770                NaN
# 11         CHEMBL83428                NaN
# 24       CHEMBL1431546                NaN
# 31       CHEMBL1498991                NaN
# ...                ...                ...
# 1920309  CHEMBL2172780  LONAZOLAC CALCIUM
# 1920310  CHEMBL1334692          LONAZOLAC
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 10                                                     NaN  Small molecule
# 11                                                     NaN  Small molecule
# 24                                                     NaN  Small molecule
# 31                                                     NaN  Small molecule
# ...

# %%
df[df['MolecularWeight'] == df['MolecularWeight'].max()]
# Out:
#               ChEMBLID Name Synonyms            Type  MaxPhase  \
# 1229023  CHEMBL2179464  NaN      NaN  Small molecule         0
#
#          MolecularWeight  Targets  Bioactivities  AlogP PolarSurfaceArea  ...  \
# 1229023         12546.32      5.0           17.0    NaN             None  ...
#
#         InorganicFlag HeavyAtoms HBA(Lipinski) HBD(Lipinski)  \
# 1229023            -1       None          None          None
#
#         #RO5Violations(Lipinski) MolecularWeight(Monoisotopic)  \
# 1229023                     None                     6453.1096
#
#         MolecularSpecies       MolecularFormula  \
# 1229023             None  C396H390F252N66O24P42
#
#                                                     Smiles  \
# 1229023  Cc1cn(CCC[n+]2ccc(-c3cc[n+](Cc4cc(C[n+]5ccc(-c...
#
#                             InchiKey
# 1229023  QGNZCKIWBILBOZ-UHFFFAOYSA-Z
#
# [1 rows x 32 columns]

# %%
df.query('MolecularWeight == MolecularWeight.max()')
# Out:
#               ChEMBLID Name Synonyms            Type  MaxPhase  \
# 1229023  CHEMBL2179464  NaN      NaN  Small molecule         0
#
#          MolecularWeight  Targets  Bioactivities  AlogP PolarSurfaceArea  ...  \
# 1229023         12546.32      5.0           17.0    NaN             None  ...
#
#         InorganicFlag HeavyAtoms HBA(Lipinski) HBD(Lipinski)  \
# 1229023            -1       None          None          None
#
#         #RO5Violations(Lipinski) MolecularWeight(Monoisotopic)  \
# 1229023                     None                     6453.1096
#
#         MolecularSpecies       MolecularFormula  \
# 1229023             None  C396H390F252N66O24P42
#
#                                                     Smiles  \
# 1229023  Cc1cn(CCC[n+]2ccc(-c3cc[n+](Cc4cc(C[n+]5ccc(-c...
#
#                             InchiKey
# 1229023  QGNZCKIWBILBOZ-UHFFFAOYSA-Z
#
# [1 rows x 32 columns]

# %%
df[df['MolecularWeight'] == df['MolecularWeight'].max()].Smiles
# Out:
# 1229023    Cc1cn(CCC[n+]2ccc(-c3cc[n+](Cc4cc(C[n+]5ccc(-c...
# Name: Smiles, dtype: object

# %%
df.query('MolecularWeight == MolecularWeight.max()').Smiles
# Out:
# 1229023    Cc1cn(CCC[n+]2ccc(-c3cc[n+](Cc4cc(C[n+]5ccc(-c...
# Name: Smiles, dtype: object

# %%
The_heaviest_molecule = df[df['MolecularWeight'] == df['MolecularWeight'].max()]
The_heaviest_molecule.Smiles
# Out:
# 1229023    Cc1cn(CCC[n+]2ccc(-c3cc[n+](Cc4cc(C[n+]5ccc(-c...
# Name: Smiles, dtype: object

# %%
df.head()
# Out:
#         ChEMBLID Name Synonyms            Type  MaxPhase  MolecularWeight  \
# 0  CHEMBL3425773  NaN      NaN  Small molecule         0           263.25
# 1  CHEMBL1998753  NaN      NaN  Small molecule         0           455.46
# 2  CHEMBL1867860  NaN      NaN  Small molecule         0           465.53
# 3   CHEMBL481686  NaN      NaN  Small molecule         0           417.55
# 4  CHEMBL1939547  NaN      NaN  Small molecule         0           328.31
#
#    Targets  Bioactivities  AlogP PolarSurfaceArea  ... InorganicFlag  \
# 0      1.0            1.0   3.04            74.23  ...            -1
# 1     56.0           56.0   2.28           100.60  ...            -1
# 2      4.0            4.0   3.49            91.56  ...            -1
# 3      1.0            2.0   4.71            48.71  ...            -1
# 4      5.0           10.0   3.69           112.06  ...            -1
#
#   HeavyAtoms HBA(Lipinski) HBD(Lipinski) #RO5Violations(Lipinski)  \
# ...

# %%
df2 = df.query('Targets > 500 & MolecularWeight < 500 & MolecularSpecies == "ACID"') # Don't forget to put 'ACID' (which is a string) into a quotation. For integer and float data types, you don't need quotation mark.
df2
# Out:
#               ChEMBLID          Name  \
# 158776    CHEMBL259084      MLN-8054
# 361195    CHEMBL512504           NaN
# 397843   CHEMBL3286797   PF-04418948
# 682178       CHEMBL174    AMPICILLIN
# 746328    CHEMBL483849           NaN
# 774467    CHEMBL221137       EMBELIN
# 935544   CHEMBL1800285     MSD-M1PAM
# 1005151   CHEMBL228043           NaN
# 1238452  CHEMBL2165191      AZD-6482
# 1389457   CHEMBL472004           NaN
# 1490558   CHEMBL558642    GSK-650394
# 1740663     CHEMBL1023    BEXAROTENE
# 1818869       CHEMBL38     TRETINOIN
# 1827291       CHEMBL50     QUERCETIN
# 1919108    CHEMBL34259  METHOTREXATE
#
#                                                   Synonyms            Type  \
# 158776                           MLN 8054|MLN-8054|MLN8054  Small molecule
# 361195                                            A-769662  Small molecule
# 397843                                         PF-04418948  Small molecule
# ...

# %%
df2.reset_index()
# Out:
#       index       ChEMBLID          Name  \
# 0    158776   CHEMBL259084      MLN-8054
# 1    361195   CHEMBL512504           NaN
# 2    397843  CHEMBL3286797   PF-04418948
# 3    682178      CHEMBL174    AMPICILLIN
# 4    746328   CHEMBL483849           NaN
# 5    774467   CHEMBL221137       EMBELIN
# 6    935544  CHEMBL1800285     MSD-M1PAM
# 7   1005151   CHEMBL228043           NaN
# 8   1238452  CHEMBL2165191      AZD-6482
# 9   1389457   CHEMBL472004           NaN
# 10  1490558   CHEMBL558642    GSK-650394
# 11  1740663     CHEMBL1023    BEXAROTENE
# 12  1818869       CHEMBL38     TRETINOIN
# 13  1827291       CHEMBL50     QUERCETIN
# 14  1919108    CHEMBL34259  METHOTREXATE
#
#                                              Synonyms            Type  \
# 0                           MLN 8054|MLN-8054|MLN8054  Small molecule
# 1                                            A-769662  Small molecule
# 2                                         PF-04418948  Small molecule
# ...

# %%
df2.reset_index(drop=True, inplace=True)
df2.head()
# Out:
#         ChEMBLID         Name  \
# 0   CHEMBL259084     MLN-8054
# 1   CHEMBL512504          NaN
# 2  CHEMBL3286797  PF-04418948
# 3      CHEMBL174   AMPICILLIN
# 4   CHEMBL483849          NaN
#
#                                             Synonyms            Type  \
# 0                          MLN 8054|MLN-8054|MLN8054  Small molecule
# 1                                           A-769662  Small molecule
# 2                                        PF-04418948  Small molecule
# 3  AMFIPEN|AMINOBENZYLPENICILLIN|AMINOBENZYLPENIC...  Small molecule
# 4                                                NaN  Small molecule
#
#    MaxPhase  MolecularWeight  Targets  Bioactivities  AlogP PolarSurfaceArea  \
# 0         1           476.87    525.0         1612.0   5.87            87.47
# 1         0           360.39    687.0          754.0   4.21            97.11
# 2         1           409.41    523.0          690.0   3.59            76.07
# ...

# %%
df2_2 = df.query('Targets > 500 | MolecularWeight < 500 | MolecularSpecies == "ACID"')
df2_2
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920331  CHEMBL3249871                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 1                                                      NaN  Small molecule
# 2                                                      NaN  Small molecule
# 3                                                      NaN  Small molecule
# 4                                                      NaN  Small molecule
# ...

# %%
df3 = df.loc[ (df['Targets'] >500 ) & (df['MolecularWeight'] < 500) & (df['MolecularSpecies'] == 'ACID') ]
df3
# Out:
#               ChEMBLID          Name  \
# 158776    CHEMBL259084      MLN-8054
# 361195    CHEMBL512504           NaN
# 397843   CHEMBL3286797   PF-04418948
# 682178       CHEMBL174    AMPICILLIN
# 746328    CHEMBL483849           NaN
# 774467    CHEMBL221137       EMBELIN
# 935544   CHEMBL1800285     MSD-M1PAM
# 1005151   CHEMBL228043           NaN
# 1238452  CHEMBL2165191      AZD-6482
# 1389457   CHEMBL472004           NaN
# 1490558   CHEMBL558642    GSK-650394
# 1740663     CHEMBL1023    BEXAROTENE
# 1818869       CHEMBL38     TRETINOIN
# 1827291       CHEMBL50     QUERCETIN
# 1919108    CHEMBL34259  METHOTREXATE
#
#                                                   Synonyms            Type  \
# 158776                           MLN 8054|MLN-8054|MLN8054  Small molecule
# 361195                                            A-769662  Small molecule
# 397843                                         PF-04418948  Small molecule
# ...

# %%
df3_2 = df.loc[ (df['Targets'] >500 ) | (df['MolecularWeight'] < 500) | (df['MolecularSpecies'] == 'ACID') ]
df3_2 = df3_2.reset_index(drop=True)
df3_2
# Out:
#               ChEMBLID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1618500  CHEMBL3249871                NaN
# 1618501  CHEMBL3958686      REMOGLIFLOZIN
# 1618502  CHEMBL1201377   MISOPROSTOL ACID
# 1618503   CHEMBL537710                NaN
# 1618504      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 1                                                      NaN  Small molecule
# 2                                                      NaN  Small molecule
# 3                                                      NaN  Small molecule
# 4                                                      NaN  Small molecule
# ...

# %%
df.groupby('MolecularSpecies').describe()
# Out:
#                    MaxPhase                                               \
#                       count      mean       std  min  25%  50%  75%  max
# MolecularSpecies
# ACID               221475.0  0.017442  0.245163  0.0  0.0  0.0  0.0  4.0
# BASE               249622.0  0.017967  0.253193  0.0  0.0  0.0  0.0  4.0
# NEUTRAL           1361262.0  0.006897  0.151881  0.0  0.0  0.0  0.0  4.0
# None                50428.0  0.041366  0.386777  0.0  0.0  0.0  0.0  4.0
# ZWITTERION          35466.0  0.022359  0.276698  0.0  0.0  0.0  0.0  4.0
#
#                  MolecularWeight              ... AlogP        InorganicFlag  \
#                            count        mean  ...   75%    max         count
# MolecularSpecies                              ...
# ACID                    221475.0  437.140644  ...  4.94  22.57      221475.0
# BASE                    249622.0  425.674308  ...  4.84  18.09      249622.0
# NEUTRAL                1361262.0  398.846751  ...  4.53  22.12     1361262.0
# ...

# %%
df.groupby('MolecularSpecies').mean()
# Out:
#                   MaxPhase  MolecularWeight   Targets  Bioactivities  \
# MolecularSpecies
# ACID              0.017442       437.140644  5.398292       8.668143
# BASE              0.017967       425.674308  5.232401       8.950160
# NEUTRAL           0.006897       398.846751  6.887467       9.913414
# None              0.041366       815.936999  7.988639      12.776405
# ZWITTERION        0.022359       438.963940  5.116404      10.332394
#
#                      AlogP  InorganicFlag
# MolecularSpecies
# ACID              3.483545      -0.989051
# BASE              3.648721      -0.987778
# NEUTRAL           3.502108      -0.995304
# None              4.241624      -0.976243
# ZWITTERION        2.380230      -0.988129

# %%
df.groupby('MolecularSpecies').sum()
# Out:
#                   MaxPhase  MolecularWeight    Targets  Bioactivities  \
# MolecularSpecies
# ACID                  3863     9.681572e+07  1138748.0      1828510.0
# BASE                  4485     1.062577e+08  1161232.0      1986318.0
# NEUTRAL               9388     5.429349e+08  9108255.0     13109885.0
# None                  2086     4.114607e+07   369858.0       591522.0
# ZWITTERION             793     1.556830e+07   167025.0       337301.0
#
#                        AlogP  InorganicFlag
# MolecularSpecies
# ACID               771518.09        -219050
# BASE               910801.12        -246571
# NEUTRAL           4767287.06       -1354869
# None                78932.38         -49230
# ZWITTERION          84417.25         -35045

# %%
df.groupby('MolecularSpecies').count()
# Out:
#                   ChEMBLID   Name  Synonyms     Type  MaxPhase  \
# MolecularSpecies
# ACID                221475   6384      9892   221475    221475
# BASE                249622   5055     14213   249622    249622
# NEUTRAL            1361262  25382     53835  1361262   1361262
# None                 50428   4931      4180    50428     50428
# ZWITTERION           35466    854      1405    35466     35466
#
#                   MolecularWeight  Targets  Bioactivities    AlogP  \
# MolecularSpecies
# ACID                       221475   210946         210946   221475
# BASE                       249622   221931         221931   249622
# NEUTRAL                   1361262  1322439        1322439  1361262
# None                        50428    46298          46298    18609
# ZWITTERION                  35466    32645          32645    35466
#
#                   PolarSurfaceArea  ...  StructureType  InorganicFlag  \
# MolecularSpecies                    ...
# ...

# %%
df.groupby('MolecularSpecies').MolecularWeight.describe()
# Out:
#                       count        mean         std    min      25%     50%  \
# MolecularSpecies
# ACID               221475.0  437.140644  147.093352  19.01  336.755  418.45
# BASE               249622.0  425.674308  139.563397  16.03  331.410  410.49
# NEUTRAL           1361262.0  398.846751  113.717659  17.02  323.420  385.51
# None                50428.0  815.936999  776.071514   4.00  321.350  496.98
# ZWITTERION          35466.0  438.963940  168.259513  75.07  329.400  421.57
#
#                         75%       max
# MolecularSpecies
# ACID               510.6100   3061.60
# BASE               497.5700   2002.35
# NEUTRAL            457.4600   1590.69
# None              1142.4275  12546.32
# ZWITTERION         523.6400   1466.38

# %%
df.groupby('MolecularSpecies').MolecularWeight.count()
# Out:
# MolecularSpecies
# ACID           221475
# BASE           249622
# NEUTRAL       1361262
# None            50428
# ZWITTERION      35466
# Name: MolecularWeight, dtype: int64

# %%
df.MolecularSpecies.isin(['ACID']).sum()
# Out:
# 221475

# %%
df.MolecularSpecies.value_counts()
# Out:
# NEUTRAL       1361262
# BASE           249622
# ACID           221475
# None            50428
# ZWITTERION      35466
# Name: MolecularSpecies, dtype: int64

# %%
df.MolecularSpecies.str.contains('ACID').sum()
# Out:
# 221475

# %%
df.sort_values('MolecularWeight')
# Out:
#               ChEMBLID                 Name  \
# 1739491  CHEMBL1796997               HELIUM
# 503047   CHEMBL1234004          LITHIUM ION
# 1907805  CHEMBL2146126              LITHIUM
# 1741579  CHEMBL2106049  CHARCOAL, ACTIVATED
# 1738199  CHEMBL1201189         AMMONIA N 13
# ...                ...                  ...
# 1919543  CHEMBL3545385               WX-037
# 1919591  CHEMBL3545236             BPI-9016
# 1919605  CHEMBL3545426               CC-115
# 1919847  CHEMBL3545134           LY-2780301
# 1919880  CHEMBL3545180          THELIATINIB
#
#                                                   Synonyms            Type  \
# 1739491      E-939|E939|HELIUM|HELIUM-4|INS NO.939|INS-939  Small molecule
# 503047                                                 NaN  Small molecule
# 1907805                                    LITHIUM|Lithium  Small molecule
# 1741579  ACTIVATED CHARCOAL|AST 120|AST-120|CARBO VEGET...  Small molecule
# ...

# %%
df.sort_values('MolecularWeight', ascending=False)
# Out:
#               ChEMBLID         Name                          Synonyms  \
# 1229023  CHEMBL2179464          NaN                               NaN
# 81431    CHEMBL2179461          NaN                               NaN
# 1515250   CHEMBL573278          NaN                               NaN
# 922946    CHEMBL499500          NaN                               NaN
# 249121   CHEMBL1255958          NaN                               NaN
# ...                ...          ...                               ...
# 1919543  CHEMBL3545385       WX-037                            WX-037
# 1919591  CHEMBL3545236     BPI-9016                BPI-9016|BPI-9016M
# 1919605  CHEMBL3545426       CC-115                            CC-115
# 1919847  CHEMBL3545134   LY-2780301                        LY-2780301
# 1919880  CHEMBL3545180  THELIATINIB  HMPL-309|THELIATINIB|XILIERTINIB
#
#                    Type  MaxPhase  MolecularWeight  Targets  Bioactivities  \
# ...

# %%
df.sort_values(by=['MolecularWeight', 'Bioactivities'], ascending=[0, 1]) # It is obvious that after sorting the first column, sorting the second column has some limitations.
# Out:
#               ChEMBLID         Name                          Synonyms  \
# 1229023  CHEMBL2179464          NaN                               NaN
# 81431    CHEMBL2179461          NaN                               NaN
# 1515250   CHEMBL573278          NaN                               NaN
# 922946    CHEMBL499500          NaN                               NaN
# 249121   CHEMBL1255958          NaN                               NaN
# ...                ...          ...                               ...
# 1919543  CHEMBL3545385       WX-037                            WX-037
# 1919591  CHEMBL3545236     BPI-9016                BPI-9016|BPI-9016M
# 1919605  CHEMBL3545426       CC-115                            CC-115
# 1919847  CHEMBL3545134   LY-2780301                        LY-2780301
# 1919880  CHEMBL3545180  THELIATINIB  HMPL-309|THELIATINIB|XILIERTINIB
#
#                    Type  MaxPhase  MolecularWeight  Targets  Bioactivities  \
# ...
