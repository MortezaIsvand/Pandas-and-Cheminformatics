# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Chembl_library_2M.csv', sep=';')
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        ChEMBL ID Name Synonyms            Type  Max Phase  Molecular Weight  \
# 0  CHEMBL3425773  NaN      NaN  Small molecule          0            263.25
# 1  CHEMBL1998753  NaN      NaN  Small molecule          0            455.46
# 2  CHEMBL1867860  NaN      NaN  Small molecule          0            465.53
# 3   CHEMBL481686  NaN      NaN  Small molecule          0            417.55
# 4  CHEMBL1939547  NaN      NaN  Small molecule          0            328.31
#
#    Targets  Bioactivities AlogP Polar Surface Area  ... Inorganic Flag  \
# 0      1.0            1.0  3.04              74.23  ...             -1
# 1     56.0           56.0  2.28             100.60  ...             -1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920338 entries, 0 to 1920337
# Data columns (total 32 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   ChEMBL ID                        object
#  1   Name                             object
#  2   Synonyms                         object
#  3   Type                             object
#  4   Max Phase                        int64
#  5   Molecular Weight                 float64
#  6   Targets                          float64
#  7   Bioactivities                    float64
#  8   AlogP                            object
#  9   Polar Surface Area               object
#  10  HBA                              object
#  11  HBD                              object
#  12  #RO5 Violations                  object
#  13  #Rotatable Bonds                 object
#  14  Passes Ro3                       object
#  15  QED Weighted                     object
# ...

# %%
df.dtypes
# Out:
# ChEMBL ID                           object
# Name                                object
# Synonyms                            object
# Type                                object
# Max Phase                            int64
# Molecular Weight                   float64
# Targets                            float64
# Bioactivities                      float64
# AlogP                               object
# Polar Surface Area                  object
# HBA                                 object
# HBD                                 object
# #RO5 Violations                     object
# #Rotatable Bonds                    object
# Passes Ro3                          object
# QED Weighted                        object
# CX Acidic pKa                       object
# CX Basic pKa                        object
# CX LogP                             object
# CX LogD                             object
# Aromatic Rings                      object
# Structure Type                      object
# ...

# %%
df.AlogP.dtype
# Out:
# dtype('O')

# %%
df.select_dtypes(include='number')
# Out:
#          Max Phase  Molecular Weight  Targets  Bioactivities  Inorganic Flag
# 0                0            263.25      1.0            1.0              -1
# 1                0            455.46     56.0           56.0              -1
# 2                0            465.53      4.0            4.0              -1
# 3                0            417.55      1.0            2.0              -1
# 4                0            328.31      5.0           10.0              -1
# ...            ...               ...      ...            ...             ...
# 1920333          0           1815.46      2.0            8.0              -1
# 1920334          0            450.53      4.0           11.0               0
# 1920335          0            368.51      NaN            NaN               0
# 1920336          0            375.76      1.0            4.0              -1
# 1920337          0            289.32      3.0            4.0               0
#
# [1920338 rows x 5 columns]

# %%
df.select_dtypes(exclude='object')
# Out:
#          Max Phase  Molecular Weight  Targets  Bioactivities  Inorganic Flag
# 0                0            263.25      1.0            1.0              -1
# 1                0            455.46     56.0           56.0              -1
# 2                0            465.53      4.0            4.0              -1
# 3                0            417.55      1.0            2.0              -1
# 4                0            328.31      5.0           10.0              -1
# ...            ...               ...      ...            ...             ...
# 1920333          0           1815.46      2.0            8.0              -1
# 1920334          0            450.53      4.0           11.0               0
# 1920335          0            368.51      NaN            NaN               0
# 1920336          0            375.76      1.0            4.0              -1
# 1920337          0            289.32      3.0            4.0               0
#
# [1920338 rows x 5 columns]

# %%
df.select_dtypes(include='object')
# Out:
#              ChEMBL ID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920333  CHEMBL1627004                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 1                                                      NaN  Small molecule
# 2                                                      NaN  Small molecule
# 3                                                      NaN  Small molecule
# 4                                                      NaN  Small molecule
# ...

# %%
df.select_dtypes(exclude='number')
# Out:
#              ChEMBL ID               Name  \
# 0        CHEMBL3425773                NaN
# 1        CHEMBL1998753                NaN
# 2        CHEMBL1867860                NaN
# 3         CHEMBL481686                NaN
# 4        CHEMBL1939547                NaN
# ...                ...                ...
# 1920333  CHEMBL1627004                NaN
# 1920334  CHEMBL3958686      REMOGLIFLOZIN
# 1920335  CHEMBL1201377   MISOPROSTOL ACID
# 1920336   CHEMBL537710                NaN
# 1920337      CHEMBL906  MINOXIDIL SULFATE
#
#                                                   Synonyms            Type  \
# 0                                                      NaN  Small molecule
# 1                                                      NaN  Small molecule
# 2                                                      NaN  Small molecule
# 3                                                      NaN  Small molecule
# 4                                                      NaN  Small molecule
# ...

# %%
df.describe()
# Out:
#           Max Phase  Molecular Weight       Targets  Bioactivities  \
# count  1.920338e+06      1.918253e+06  1.835637e+06   1.835637e+06
# mean   1.114543e-02      4.184655e+02  6.528624e+00   9.748372e+00
# std    1.952130e-01      1.872083e+02  1.432113e+01   4.957730e+01
# min    0.000000e+00      4.000000e+00  1.000000e+00   1.000000e+00
# 25%    0.000000e+00      3.254500e+02  1.000000e+00   2.000000e+00
# 50%    0.000000e+00      3.934100e+02  3.000000e+00   4.000000e+00
# 75%    0.000000e+00      4.722000e+02  6.000000e+00   9.000000e+00
# max    4.000000e+00      1.254632e+04  1.332000e+03   1.778000e+04
#
#        Inorganic Flag
# count    1.920338e+06
# mean    -9.926633e-01
# std      8.653368e-02
# min     -1.000000e+00
# 25%     -1.000000e+00
# 50%     -1.000000e+00
# 75%     -1.000000e+00
# max      1.000000e+00

# %%
df.AlogP.value_counts()
# Out:
# None     31819
# 3.40      4851
# 3.30      4836
# 3.34      4766
# 3.47      4752
#          ...
# -7.03        1
# -9.17        1
# -7.21        1
# 14.71        1
# -8.95        1
# Name: AlogP, Length: 2476, dtype: int64

# %%
df.AlogP.replace('None', np.nan, inplace=True)

# %%
df.AlogP.astype(float)
# Out:
# 0          3.04
# 1          2.28
# 2          3.49
# 3          4.71
# 4          3.69
#            ...
# 1920333     NaN
# 1920334    1.33
# 1920335    3.87
# 1920336    0.82
# 1920337   -1.59
# Name: AlogP, Length: 1920338, dtype: float64

# %%
df.dtypes            # The dtype of the 'AlogP' column has not yet changed.
# Out:
# ChEMBL ID                           object
# Name                                object
# Synonyms                            object
# Type                                object
# Max Phase                            int64
# Molecular Weight                   float64
# Targets                            float64
# Bioactivities                      float64
# AlogP                               object
# Polar Surface Area                  object
# HBA                                 object
# HBD                                 object
# #RO5 Violations                     object
# #Rotatable Bonds                    object
# Passes Ro3                          object
# QED Weighted                        object
# CX Acidic pKa                       object
# CX Basic pKa                        object
# CX LogP                             object
# CX LogD                             object
# Aromatic Rings                      object
# Structure Type                      object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920338 entries, 0 to 1920337
# Data columns (total 32 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   ChEMBL ID                        object
#  1   Name                             object
#  2   Synonyms                         object
#  3   Type                             object
#  4   Max Phase                        int64
#  5   Molecular Weight                 float64
#  6   Targets                          float64
#  7   Bioactivities                    float64
#  8   AlogP                            object
#  9   Polar Surface Area               object
#  10  HBA                              object
#  11  HBD                              object
#  12  #RO5 Violations                  object
#  13  #Rotatable Bonds                 object
#  14  Passes Ro3                       object
#  15  QED Weighted                     object
# ...

# %%
df.AlogP.dtype
# Out:
# dtype('O')

# %%
df['AlogP'] = df['AlogP'].astype(float) # To save changes. # You can also use df['AlogP'] = pd.to_numeric(df['AlogP'])

# %%
df.dtypes             # As you can see, the dtype of the 'AlogP' column has been changed.
# Out:
# ChEMBL ID                           object
# Name                                object
# Synonyms                            object
# Type                                object
# Max Phase                            int64
# Molecular Weight                   float64
# Targets                            float64
# Bioactivities                      float64
# AlogP                              float64
# Polar Surface Area                  object
# HBA                                 object
# HBD                                 object
# #RO5 Violations                     object
# #Rotatable Bonds                    object
# Passes Ro3                          object
# QED Weighted                        object
# CX Acidic pKa                       object
# CX Basic pKa                        object
# CX LogP                             object
# CX LogD                             object
# Aromatic Rings                      object
# Structure Type                      object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920338 entries, 0 to 1920337
# Data columns (total 32 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   ChEMBL ID                        object
#  1   Name                             object
#  2   Synonyms                         object
#  3   Type                             object
#  4   Max Phase                        int64
#  5   Molecular Weight                 float64
#  6   Targets                          float64
#  7   Bioactivities                    float64
#  8   AlogP                            float64
#  9   Polar Surface Area               object
#  10  HBA                              object
#  11  HBD                              object
#  12  #RO5 Violations                  object
#  13  #Rotatable Bonds                 object
#  14  Passes Ro3                       object
#  15  QED Weighted                     object
# ...

# %%
df.AlogP.dtype
# Out:
# dtype('float64')

# %%
df.describe()
# Out:
#           Max Phase  Molecular Weight       Targets  Bioactivities  \
# count  1.920338e+06      1.918253e+06  1.835637e+06   1.835637e+06
# mean   1.114543e-02      4.184655e+02  6.528624e+00   9.748372e+00
# std    1.952130e-01      1.872083e+02  1.432113e+01   4.957730e+01
# min    0.000000e+00      4.000000e+00  1.000000e+00   1.000000e+00
# 25%    0.000000e+00      3.254500e+02  1.000000e+00   2.000000e+00
# 50%    0.000000e+00      3.934100e+02  3.000000e+00   4.000000e+00
# 75%    0.000000e+00      4.722000e+02  6.000000e+00   9.000000e+00
# max    4.000000e+00      1.254632e+04  1.332000e+03   1.778000e+04
#
#               AlogP  Inorganic Flag
# count  1.886434e+06    1.920338e+06
# mean   3.505533e+00   -9.926633e-01
# std    1.883058e+00    8.653368e-02
# min   -1.426000e+01   -1.000000e+00
# 25%    2.380000e+00   -1.000000e+00
# 50%    3.480000e+00   -1.000000e+00
# 75%    4.620000e+00   -1.000000e+00
# max    2.257000e+01    1.000000e+00

# %%
df.select_dtypes(include='number')
# Out:
#          Max Phase  Molecular Weight  Targets  Bioactivities  AlogP  \
# 0                0            263.25      1.0            1.0   3.04
# 1                0            455.46     56.0           56.0   2.28
# 2                0            465.53      4.0            4.0   3.49
# 3                0            417.55      1.0            2.0   4.71
# 4                0            328.31      5.0           10.0   3.69
# ...            ...               ...      ...            ...    ...
# 1920333          0           1815.46      2.0            8.0    NaN
# 1920334          0            450.53      4.0           11.0   1.33
# 1920335          0            368.51      NaN            NaN   3.87
# 1920336          0            375.76      1.0            4.0   0.82
# 1920337          0            289.32      3.0            4.0  -1.59
#
#          Inorganic Flag
# 0                    -1
# 1                    -1
# 2                    -1
# 3                    -1
# ...
